# %% [markdown]
# # InspireScraper Notebook
#
# This notebook is used for scraping academic paper information from INSPIRE-HEP.

# %%
# Import necessary libraries and functions

from src.imports import *
from src.utils import scrape_all_pages, fetch_abstract, get_total_pages_from_inspire, add_abstracts

# %% [markdown]
# ## Initialize WebDriver
#
# Here we initialize the WebDriver for Selenium.

# %%
driver = webdriver.Safari()  # Or whichever driver you're using

# %% [markdown]
# ## Scrape Data from INSPIRE-HEP
#
# Define the base URL to scrape. do not worry if the first page of the query doen not contain all the papers. The script will take care of that for you.

# %%
url = "https://inspirehep.net/literature?sort=mostrecent&size=250&page=1&q=a%20quevedo&ui-citation-summary=true"

# %% [markdown]
# The following cell runs the scraper.

# %%
df = scrape_all_pages(driver, url)
# Out:
# https://inspirehep.net/literature?sort=mostrecent&size=250&q=a%20quevedo&ui-citation-summary=true

# %%
df.head()
# Out:
#                                                                     Title  \
# 0         Quasi-periodic oscillations in rotating and deformed spacetimes
# 1                              Extended black hole geometrothermodynamics
# 2  Euclid preparation. TBD. Galaxy power spectrum modelling in real space
# 3               Gravitational repulsive effects in 3D regular black holes
# 4                                   Moduli Stabilization in String Theory
#
#                                                                                    Authors  \
# 0  Kuantay Boshkayev, Talgar Konysbayev, Yergali Kurmanov, Marco Muccino, Hernando Quevedo
# 1                                                                         Hernando Quevedo
# 2                                                                              A. Pezzotta
# 3                                            Orlando Luongo, Hernando Quevedo, S.N. Sajadi
# ...

# %% [markdown]
# ## Add abstracts
#
# The following cell adds abstracts to the dataframe, in case you need them for subsequent analyses. Be aware that this might be time-consuming.

# %%
df_abs = add_abstracts(df)

# %%
df_abs
# Out:
#                                                                                  Title  \
# 0                      Quasi-periodic oscillations in rotating and deformed spacetimes
# 1                                           Extended black hole geometrothermodynamics
# 2               Euclid preparation. TBD. Galaxy power spectrum modelling in real space
# 3                            Gravitational repulsive effects in 3D regular black holes
# 4                                                Moduli Stabilization in String Theory
# ..                                                                                 ...
# 444  Class of Stationary Axisymmetric Solutions of Einstein's Equations in Empty Space
# 445                                 COMPACTIFICATION OF CHIRAL N=2 D = 10 SUPERGRAVITY
# 446                                    Low-Energy Effective Action for the Superstring
# 447                           ELECTROVAC COMPACTIFICATION OF GAUGED d = 7 SUPERGRAVITY
# ...

# %% [markdown]
# # Produce basic plots

# %%
from src.utils import plot_arxiv_category_distribution
plot_arxiv_category_distribution(df)

# %%
from src.utils import plot_citations_per_category
plot_citations_per_category(df)

# %%
from src.utils import plot_pareto_authors
plot_pareto_authors(df)
